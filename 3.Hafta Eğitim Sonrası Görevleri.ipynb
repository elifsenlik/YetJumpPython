# %% [markdown]
# # Problem 1
# Kullanıcıdan bir sayı alınız. Sayı 0'dan büyükse pozitif , 0'dan küçükse negatif sıfıra eşitse sıfır yazdırınız.

# %%
# 1.Problemin Çözümünü Buraya Yazınız
sayi =int(input ("Bir sayı giriniz = "))
if (sayi>0):
    print("pozitif")
elif (sayi <0):
    print("negatif")
else:
    print("sıfır")
# Out:
# pozitif

# %% [markdown]
#  # Problem 2
# Kullanıcıdan aldığınız bir sayının mükemmel olup olmadığını bulmaya çalışın.
# Bir sayının kendi hariç bölenlerinin toplamı kendine eşitse bu sayıya "mükemmel sayı" denir. Örnek olarak, 6 mükemmel bir sayıdır. (1 + 2 + 3 = 6)

# %%
# 2.Problemin Çözümünü Buraya Yazınız
sayi2 =int(input ("Bir sayı giriniz = "))
toplam = 0
for i in range(1,sayi2):
    if (((sayi2) % (i)) == 0 ):
        toplam = toplam+ i
if (toplam == sayi2):
    print(" %d mükemmel sayıdır" %sayi2)
else:
    print(" %d mükemmel sayı değildir" %sayi2)
# Out:
#  40 mükemmel sayı değildir

# %% [markdown]
#  # Problem 3
# Kullanıcıdan aldığınız bir sayının "Armstrong" sayısı olup olmadığını bulmaya çalışın.
# Örnek olarak, Bir sayı eğer 4 basamaklı ise ve oluşturan rakamlardan herbirinin 4. kuvvetinin toplamı( 3 basamaklı sayılar için 3.kuvveti ) o sayıya eşitse bu sayıya "Armstrong" sayısı denir.
#
# Örnek olarak : 1634 = 1^4 + 6^4 + 3^4 + 4^4

# %%
# 3.Problemin Çözümünü Buraya Yazınız
sayi3 =str(input ("Bir sayı giriniz = "))
a=[]
toplam =0
# print(str(sayi3[1]))
if (int(sayi3) > 999):
    for i in (sayi3):
        toplam += int(i)**4
        a.append(i)
        
        if ( toplam == int(sayi3)):
            print("%d bu sayi Armstrong sayıdır" %int(sayi3))
# Out:
# 1634 bu sayi Armstrong sayıdır

# %% [markdown]
# # Problem 4
# YetGen Core Python mezunu bir öğretmenimiz öğrencilerine 1'den 10'a kadar sayılarla çarpım tablosunu öğretirken Python'dan destek almak istiyor. Bu konuda öğretmenimize yardımcı olmak ister misin?
#
# İpucu: İç içe 2 tane for döngüsü kullanın.
#
# Aynı zamanda sayıları range() fonksiyonunu kullanarak elde edin.

# %%
# 4.Problemin Çözümünü Buraya Yazınız
print("ÇARPIM TABLOSU:")
for i in range (1,11):
    for j in range (1,11):
        carpım = i*j
        print("%d x %d = %d " %(i, j, carpım))
# Out:
# ÇARPIM TABLOSU:
# 1 x 1 = 1
# 1 x 2 = 2
# 1 x 3 = 3
# 1 x 4 = 4
# 1 x 5 = 5
# 1 x 6 = 6
# 1 x 7 = 7
# 1 x 8 = 8
# 1 x 9 = 9
# 1 x 10 = 10
# 2 x 1 = 2
# 2 x 2 = 4
# 2 x 3 = 6
# 2 x 4 = 8
# 2 x 5 = 10
# 2 x 6 = 12
# 2 x 7 = 14
# 2 x 8 = 16
# 2 x 9 = 18
# 2 x 10 = 20
# 3 x 1 = 3
# 3 x 2 = 6
# 3 x 3 = 9
# 3 x 4 = 12
# 3 x 5 = 15
# 3 x 6 = 18
# 3 x 7 = 21
# 3 x 8 = 24
# 3 x 9 = 27
# 3 x 10 = 30
# 4 x 1 = 4
# 4 x 2 = 8
# 4 x 3 = 12
# 4 x 4 = 16
# 4 x 5 = 20
# 4 x 6 = 24
# 4 x 7 = 28
# 4 x 8 = 32
# 4 x 9 = 36
# 4 x 10 = 40
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50
# 6 x 1 = 6
# 6 x 2 = 12
# 6 x 3 = 18
# 6 x 4 = 24
# 6 x 5 = 30
# 6 x 6 = 36
# 6 x 7 = 42
# 6 x 8 = 48
# 6 x 9 = 54
# 6 x 10 = 60
# 7 x 1 = 7
# 7 x 2 = 14
# 7 x 3 = 21
# 7 x 4 = 28
# 7 x 5 = 35
# 7 x 6 = 42
# 7 x 7 = 49
# 7 x 8 = 56
# 7 x 9 = 63
# 7 x 10 = 70
# 8 x 1 = 8
# 8 x 2 = 16
# 8 x 3 = 24
# 8 x 4 = 32
# 8 x 5 = 40
# 8 x 6 = 48
# 8 x 7 = 56
# 8 x 8 = 64
# 8 x 9 = 72
# 8 x 10 = 80
# 9 x 1 = 9
# 9 x 2 = 18
# 9 x 3 = 27
# 9 x 4 = 36
# 9 x 5 = 45
# 9 x 6 = 54
# 9 x 7 = 63
# 9 x 8 = 72
# 9 x 9 = 81
# 9 x 10 = 90
# 10 x 1 = 10
# 10 x 2 = 20
# 10 x 3 = 30
# 10 x 4 = 40
# 10 x 5 = 50
# 10 x 6 = 60
# 10 x 7 = 70
# 10 x 8 = 80
# 10 x 9 = 90
# 10 x 10 = 100

# %% [markdown]
# # Problem 5
# Markete giren bir YetGen'li sıra beklememek için hızlı kasaya gider. Hızlı kasanın çalışma mantığı şu şekildedir:
# - Kullanıcının aldığı her ürünün fiyatını tek tek girmesi gerekir.
# - Kullanıcı kasadan çıkmak isterse q tuşuna basmalıdır.
# - Kasa girilen fiyatları son fiyat isimli değişkene ekler.
# - Değişkeni ekrana bastırır.
#
# İpucu: while döngüsünü sonsuz koşulla başlatın ve kullanıcı q'ya basarsa döngüyü break ile sonlandırın.

# %%
# 5.Problemin Çözümünü Buraya Yazınız
sonFiyat=0
while (1>0):
    deger = input("ürünlerin fiyatlarını tek tek giriniz : ")
    if (deger == "q"):
        break
    else:
        sonFiyat = int(deger) + int(sonFiyat)
print ("%d TL: toplam alışveriş tutarı"%sonFiyat)
# Out:
# 160 TL: toplam alışveriş tutarı

# %% [markdown]
# # Problem 6
# 1'den 100'e kadar olan sayılardan sadece 3'e bölünen sayıları ekrana bastırın. Bu işlemi continue ile yapmaya çalışın.

# %%
# 6.Problemin Çözümünü Buraya Yazınız

for i in range(1,101):
    if i % 3 ==0:
        print(i)
    elif i%3!=0:
        continue
# Out:
# 3
# 6
# 9
# 12
# 15
# 18
# 21
# 24
# 27
# 30
# 33
# 36
# 39
# 42
# 45
# 48
# 51
# 54
# 57
# 60
# 63
# 66
# 69
# 72
# 75
# 78
# 81
# 84
# 87
# 90
# 93
# 96
# 99

# %% [markdown]
# # Problem 7
# Bir YetGen Core Python mezunu MEF Üniversitesi'nde Bilgisayar Bilimleri Doktora programının mülakatına girmeye hak kazanıyor. Mülakata hazırlanırken internetten soru araştırıyor. Karşısına çıkan ünlü FizzBuzz sorusuna benzer YetGen sorusunda kendisini yeterince hazır hissetmiyor. Bu soruyu çözmesine destek olmak ister misin?
#
# Soru aşağıdaki gibidir:
#
# 1’den 100’e kadar sayıları yazdırıyoruz. Ancak eğer sayı 3’e bölünüyor ise Yet, sayı 5’e bölünüyorsa Gen, hem 3’e hem 5’e bölünüyorsa YetGen yazdırıyoruz.

# %%
# 7.Problemin Çözümünü Buraya Yazınız


for i in range(1,101):
    if i % 3 ==0:
        if i % 5 ==0:
            print('%d : YETGEN ' %i)
        elif i % 5 !=0:
            print('%d : YET' %i)
    elif i % 5 ==0:
        print('%d : GEN' %i)
# Out:
# 3 : YET
# 5 : GEN
# 6 : YET
# 9 : YET
# 10 : GEN
# 12 : YET
# 15 : YETGEN
# 18 : YET
# 20 : GEN
# 21 : YET
# 24 : YET
# 25 : GEN
# 27 : YET
# 30 : YETGEN
# 33 : YET
# 35 : GEN
# 36 : YET
# 39 : YET
# 40 : GEN
# 42 : YET
# 45 : YETGEN
# 48 : YET
# 50 : GEN
# 51 : YET
# 54 : YET
# 55 : GEN
# 57 : YET
# 60 : YETGEN
# 63 : YET
# 65 : GEN
# 66 : YET
# 69 : YET
# 70 : GEN
# 72 : YET
# 75 : YETGEN
# 78 : YET
# 80 : GEN
# 81 : YET
# 84 : YET
# 85 : GEN
# 87 : YET
# 90 : YETGEN
# 93 : YET
# 95 : GEN
# 96 : YET
# 99 : YET
# 100 : GEN
